# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df=pd.read_csv('winequality-white.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
X = .22 

list_1 = [7.8+X, .88+X, 0.00+X, 1.9, 0.09+X, 25.0+X, 67.0+X, .991+X, 3.22, 0.68+X, 9.8+X, 5]
list_2 = [7.2+X, .83+X, 0.01+X, 2.2, 0.19+X, 15.0+X, 60.0+X, .996+X, 3.52, 0.55+X, 9.6+X, 6]
list_3=[7.9+X, .89+X, 0.01+X, 1.7, 0.08+X, 22.0+X, 57.0+X, .997+X, 3.26, 0.64+X, 9.8+X, 2]
list_4=[7.7+X, .86+X, 0.02+X, 2.3, 0.07+X, 11.0+X, 38.0+X, .994+X, 3.12, 0.08+X, 9.4+X, 3]

#row=[row_1,row_2,row_3,row_4]

# %%
row_1=pd.DataFrame([list_1],columns=df.columns)
row_2=pd.DataFrame([list_2],columns=df.columns)
row_3=pd.DataFrame([list_3],columns=df.columns)
row_4=pd.DataFrame([list_4],columns=df.columns)

# %%
row_4
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0           7.92              1.08         0.24             2.3       0.29
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                11.22                 38.22    1.214  3.12        0.3
#
#    alcohol  quality
# 0     9.62        3

# %%
# Appending the new row to the original DataFrame
df = df.append(row_1, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_11131/2890272555.py in ?()
#       1 # Appending the new row to the original DataFrame
# ----> 2 df = df.append(row_1, ignore_index=True)
#
# ~/Project/telecom_customer_churn/venv/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
xtra = {
        'fixed acidity': [7.8+X,7.2+X,7.9+X,7.7+X], 
        'volatile acidity': [.88+X,.83+X,.89+X,.86+X],
        'citric acid': [0.00+X,0.01+X,0.01+X,0.02+X],
        'residual sugar':[1.9,2.2,1.7,2.3],
        'chlorides':[0.09+X,0.19+X,0.08+X,0.07+X],
        'free sulfur dioxide':[25.0+X,15.0+X,22.0+X,11.0+X],
        'total sulfur dioxide': [67.0+X,60.0+X,57.0+X,38.0+X],
        'density': [.991+X,.996+X,.997+X,.994+X],
        'pH': [3.22,3.52,3.26,3.12],
        'sulphates': [0.68+X,0.55+X,0.64+X,0.08+X],
        'alcohol': [9.8+X,9.6+X,9.8+X,9.4+X],
        'quality': [5,6,2,3]
        
        }
xtra_df=pd.DataFrame(xtra)
#df=df+xtra_df
xtra_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0           8.02              1.10         0.22             1.9       0.31
# 1           7.42              1.05         0.23             2.2       0.41
# 2           8.12              1.11         0.23             1.7       0.30
# 3           7.92              1.08         0.24             2.3       0.29
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                25.22                 67.22    1.211  3.22       0.90
# 1                15.22                 60.22    1.216  3.52       0.77
# 2                22.22                 57.22    1.217  3.26       0.86
# 3                11.22                 38.22    1.214  3.12       0.30
#
#    alcohol  quality
# 0    10.02        5
# 1     9.82        6
# 2    10.02        2
# 3     9.62        3

# %%
xtra_df.shape
# Out:
# (4, 12)

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
df.shape
# Out:
# (4898, 12)

# %%
# Concatenate along rows (axis=0)
result_df = pd.concat([df, xtra_df], ignore_index=True)

# %%
result_df.shape
# Out:
# (4902, 12)

# %%
result_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
result_df.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4897           6.00              0.21         0.38             0.8       0.02
# 4898           8.02              1.10         0.22             1.9       0.31
# 4899           7.42              1.05         0.23             2.2       0.41
# 4900           8.12              1.11         0.23             1.7       0.30
# 4901           7.92              1.08         0.24             2.3       0.29
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4897                22.00                 98.00  0.98941  3.26       0.32
# 4898                25.22                 67.22  1.21100  3.22       0.90
# 4899                15.22                 60.22  1.21600  3.52       0.77
# 4900                22.22                 57.22  1.21700  3.26       0.86
# 4901                11.22                 38.22  1.21400  3.12       0.30
#
#       alcohol  quality
# 4897    11.80        6
# ...
