# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df=pd.read_csv('winequality-white.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
df.shape
# Out:
# (4898, 12)

# %%
# last two digit of my id is 22
# for better calculation i used X=0.22

X=0.22

xtra = {
        'fixed acidity': [7.8+X,7.2+X,7.9+X,7.7+X], 
        'volatile acidity': [.88+X,.83+X,.89+X,.86+X],
        'citric acid': [0.00+X,0.01+X,0.01+X,0.02+X],
        'residual sugar':[1.9,2.2,1.7,2.3],
        'chlorides':[0.09+X,0.19+X,0.08+X,0.07+X],
        'free sulfur dioxide':[25.0+X,15.0+X,22.0+X,11.0+X],
        'total sulfur dioxide': [67.0+X,60.0+X,57.0+X,38.0+X],
        'density': [.991+X,.996+X,.997+X,.994+X],
        'pH': [3.22,3.52,3.26,3.12],
        'sulphates': [0.68+X,0.55+X,0.64+X,0.08+X],
        'alcohol': [9.8+X,9.6+X,9.8+X,9.4+X],
        'quality': [5,6,2,3]
        
        }
xtra_df=pd.DataFrame(xtra)
#df=df+xtra_df
xtra_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0           8.02              1.10         0.22             1.9       0.31
# 1           7.42              1.05         0.23             2.2       0.41
# 2           8.12              1.11         0.23             1.7       0.30
# 3           7.92              1.08         0.24             2.3       0.29
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                25.22                 67.22    1.211  3.22       0.90
# 1                15.22                 60.22    1.216  3.52       0.77
# 2                22.22                 57.22    1.217  3.26       0.86
# 3                11.22                 38.22    1.214  3.12       0.30
#
#    alcohol  quality
# 0    10.02        5
# 1     9.82        6
# 2    10.02        2
# 3     9.62        3

# %%
# Concatenate along rows (axis=0)
new_df = pd.concat([df, xtra_df], ignore_index=True)

# %%
new_df.shape
# Out:
# (4902, 12)

# %%
df=new_df

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
df.shape
# Out:
# (4902, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4902 entries, 0 to 4901
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4902 non-null   float64
#  1   volatile acidity      4902 non-null   float64
#  2   citric acid           4902 non-null   float64
#  3   residual sugar        4902 non-null   float64
#  4   chlorides             4902 non-null   float64
#  5   free sulfur dioxide   4902 non-null   float64
#  6   total sulfur dioxide  4902 non-null   float64
#  7   density               4902 non-null   float64
#  8   pH                    4902 non-null   float64
#  9   sulphates             4902 non-null   float64
#  10  alcohol               4902 non-null   float64
#  11  quality               4902 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.7 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4902.000000       4902.000000  4902.000000     4902.000000
# mean        6.855616          0.278899     0.334106        6.387852
# std         0.844057          0.103356     0.121007        5.071525
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.110000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4902.000000          4902.000000           4902.000000  4902.000000
# mean      0.046002            35.294345            138.293223     0.994207
# std       0.023314            17.007731             42.547325     0.006970
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),annot =True)
# Out:
# <Axes: >

# %%
corr = df.corr()[['quality']]
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %% [markdown]
# # Analyze each feature

# %%
df.head(2)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
#
#    free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# 0                 45.0                 170.0    1.001  3.0       0.45
# 1                 14.0                 132.0    0.994  3.3       0.49
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6

# %% [markdown]
# #  quality

# %%
sns.countplot(x='quality',data=df)
# Out:
# <Axes: xlabel='quality', ylabel='count'>

# %% [markdown]
# # 	fixed acidity

# %%
sns.histplot(x='fixed acidity',data=df)
# Out:
# <Axes: xlabel='fixed acidity', ylabel='Count'>

# %% [markdown]
# # volatile acidity

# %%
sns.histplot(x='volatile acidity',data=df)
# Out:
# <Axes: xlabel='volatile acidity', ylabel='Count'>

# %% [markdown]
# # 	citric acid

# %%
sns.histplot(x='citric acid',kde=True,data=df)
# Out:
# <Axes: xlabel='citric acid', ylabel='Count'>

# %% [markdown]
# # residual sugar

# %%
sns.histplot(x='residual sugar',kde=True,data=df)
# Out:
# <Axes: xlabel='residual sugar', ylabel='Count'>

# %% [markdown]
# # chlorides

# %%
sns.histplot(x='chlorides',kde=True,data=df)
# Out:
# <Axes: xlabel='chlorides', ylabel='Count'>

# %% [markdown]
# # free sulfur dioxide

# %%
sns.histplot(x='free sulfur dioxide',kde=True,data=df)
# Out:
# <Axes: xlabel='free sulfur dioxide', ylabel='Count'>

# %% [markdown]
# # total sulfur dioxide

# %%
sns.histplot(x='total sulfur dioxide',kde=True,data=df)
# Out:
# <Axes: xlabel='total sulfur dioxide', ylabel='Count'>

# %% [markdown]
# # density

# %%
sns.histplot(x='density',kde=True,data=df)
# Out:
# <Axes: xlabel='density', ylabel='Count'>

# %% [markdown]
# # pH

# %%
sns.histplot(x='pH',kde=True,data=df)
# Out:
# <Axes: xlabel='pH', ylabel='Count'>

# %% [markdown]
# # sulphates

# %%
sns.histplot(x='sulphates',kde=True,data=df)
# Out:
# <Axes: xlabel='sulphates', ylabel='Count'>

# %% [markdown]
# # alcohol

# %%
sns.histplot(x='alcohol',kde=True,data=df)
# Out:
# <Axes: xlabel='alcohol', ylabel='Count'>

# %% [markdown]
# # EDA

# %%
df['quality'].unique()
# Out:
# array([6, 5, 7, 8, 4, 3, 9, 2])

# %%
df['quality'].dtype
# Out:
# dtype('int64')

# %%
#  0 - 5 = bad wine 
# 6 - 10 = good 

# first convert quality to int
df['quality'] = df['quality'].astype(int)

# list of quality in string
quality_list = { 3: 'bad', 4: 'bad', 5: 'bad', 6: 'good', 7: 'good', 8: 'good', 9: 'good', 10: 'good'}

# map quality to string
df['quality'] = df['quality'].map(quality_list)

print(df['quality'].value_counts())
# Out:
# good    3259
# bad     1642
# Name: quality, dtype: int64

# %%
df['quality'].unique()
# Out:
# array(['good', 'bad', nan], dtype=object)

# %%
df['quality'].value_counts()
# Out:
# good    3259
# bad     1642
# Name: quality, dtype: int64

# %%
df.shape
# Out:
# (4902, 12)

# %%
3259+1642
# Out:
# 4901

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 1
# dtype: int64

# %%
df=df.dropna()
df.shape
# Out:
# (4901, 12)

# %%
#df[df['quality']!='good' and df['quality']!='bad']

# %% [raw]
# if df['quality'] > 5:
#     condition=df['quality']
#     df.loc[condition, 'quality'] = 'good'
# else:
#     condition_for_bad=df['quality']
#     df.loc[condition_for_bad, 'quality'] = 'bad'

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol quality
# 0      8.8    good
# 1      9.5    good
# 2     10.1    good
# ...

# %%
sns.pairplot(df)

# %%
# # Dividing dependent and independent variables
X = df.drop("quality", axis=1)
y = df["quality"]

# %%
# train-test-split

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
# Feature Scaling

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# # Machine Learning

# %%
# Logistic Regression

from sklearn.linear_model import LogisticRegression  

classifier= LogisticRegression(random_state=0)  
lr_model=classifier.fit(X_train, y_train)
y_pred=lr_model.predict(X_test)

# %%
# Accuracy = TP+TN/TP+FP+FN+TN
# Precision = TP/TP+FP
# Recall = TP/TP+FN
#F1 Score = 2*(Recall * Precision) / (Recall + Precision)


from sklearn.metrics import classification_report, confusion_matrix 
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          bad       0.65      0.51      0.57       325
#         good       0.78      0.87      0.82       656
#
#     accuracy                           0.75       981
#    macro avg       0.72      0.69      0.70       981
# weighted avg       0.74      0.75      0.74       981

# %%
#x_axis_labels = ['Not Exit','Exit']
#y_axis_labels = ['Not Exit','Exit']

confusion_m=confusion_matrix(y_test,y_pred)
sns.heatmap(confusion_m, annot=True,cmap='Greens')

# , xticklabels=x_axis_labels, yticklabels=y_axis_labels


plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
# Out:
# Text(50.722222222222214, 0.5, 'Actual Label')

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
dt_model = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = dt_model.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          bad       0.63      0.69      0.66       325
#         good       0.84      0.80      0.82       656
#
#     accuracy                           0.76       981
#    macro avg       0.73      0.74      0.74       981
# weighted avg       0.77      0.76      0.77       981

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(n_estimators=100,random_state=0)
rf_model=clf.fit(X_train, y_train)
y_pred=rf_model.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          bad       0.77      0.71      0.74       325
#         good       0.86      0.90      0.88       656
#
#     accuracy                           0.84       981
#    macro avg       0.82      0.81      0.81       981
# weighted avg       0.83      0.84      0.83       981

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn.svm import SVC


# Create an SVM classifier
svm_classifier = SVC(random_state=0)

# Fit the SVM model to the training data
svm_model = svm_classifier.fit(X_train, y_train)

# Make predictions on the test data
y_pred_svm = svm_model.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          bad       0.77      0.71      0.74       325
#         good       0.86      0.90      0.88       656
#
#     accuracy                           0.84       981
#    macro avg       0.82      0.81      0.81       981
# weighted avg       0.83      0.84      0.83       981
